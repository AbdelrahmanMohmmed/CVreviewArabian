# %%
import pandas as pd
import re
import spacy
from collections import defaultdict, Counter
from tqdm import tqdm

# %%
nlp = spacy.load('en_core_web_sm', disable=['ner'])  # Keep parser for noun chunks

# %%
generic_terms = {
    'large', 'include', 'provide', 'process', 'business', 'collaborate', 'ensure', 
    'maintain', 'develop', 'analyze', 'identify', 'monitor', 'level', 'report', 
    'assess', 'build', 'clean', 'design', 'generate', 'management', 'opportunity', 
    'performance', 'planning', 'strategy', 'advantage', 'knowledge', 'recommendation',
    'datum', 'load', 'etl', 'extract', 'transform', 'analytic', 'scientist', 'data',
    'preprocess', 'availability', 'accessibility', 'pipeline', 'technology', 'big',
    'warehouse', 'programming', 'evaluation', 'parameter', 'finetune', 'training',
    'algorithm', 'model', 'prediction', 'learning', 'machine', 'spark', 'hadoop',
    'deep', 'integration', 'reporting', 'collaborate', 'analyst', 'ensure', 'maintain',
    'shipment', 'track', 'optimize', 'costsave', 'problemsolve', 'logistic', 'transportation',
    'warehousing', 'inventory', 'chain', 'supply', 'level', 'monitor', 'opportunity',
    'include', 'planning', 'identify', 'trend', 'industry', 'market', 'competitive',
    'research', 'offering', 'positioning', 'competitor', 'product'
}

# %%
df = pd.read_csv('/home/jax/CVreviewArabian/data/preprocessed/sampled_cleaned.csv')

# %%
df['combined_text'] = df['skills'] + ' ' + df['Responsibilities']

# %%
def preprocess_text(text):
    text = re.sub(r'[^\w\s]', '', text.lower())
    doc = nlp(text)
    tokens = [token.lemma_ for token in doc if token.is_alpha and not token.is_stop and token.lemma_ not in generic_terms]
    return tokens  # Return only tokens for frequency counting

# %%
job_tokens = defaultdict(list)
tqdm.pandas()
for _, row in tqdm(df.iterrows(), total=df.shape[0], desc="Collecting tokens per job"):
    job = row['Job Title']
    tokens = preprocess_text(row['combined_text'])
    job_tokens[job].extend(tokens)
# Out:
# Collecting tokens per job: 100%|██████████| 161594/161594 [15:48<00:00, 170.31it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 11
#       9 skill_map = {}
#      10 for job, tokens in job_tokens.items():
# ---> 11     word_counts = Counter(tokens)
#      12     top_words = [word for word, _ in word_counts.most_common(40)]
#      13     skill_map[job] = top_words
#
# NameError: name 'Counter' is not defined

# %%
skill_map = {}
for job, tokens in job_tokens.items():
    word_counts = Counter(tokens)
    top_words = [word for word, _ in word_counts.most_common(40)]
    skill_map[job] = top_words

# %%
(skill_map)
# Out:
# {'Speech Therapist': ['speech',
#   'therapy',
#   'communication',
#   'disorder',
#   'language',
#   'skill',
#   'assessment',
#   'adult',
#   'swallow',
#   'speechlanguage',
#   'plan',
#   'child',
#   'development',
#   'technique',
#   'individual',
#   'articulation',
#   'treat',
#   'rehabilitation',
#   'focus',
#   'challenge',
#   'address',
#   'aphasia',
#   'difficulty',
#   'customize',
#   'need',
#   'pediatric',
#   'individualized',
#   'treatment',
#   'parent',
#   'educator',
#   'pathology',
#   'diagnose',
#   'wide',
#   'range',
#   'age',
#   'group',
#   'use',
#   'tool',
#   'therapeutic',
#   'help'],
#  'Architectural Designer': ['interior',
#   'architect',
#   'space',
#   'color',
#   'collaboration',
#   'cad',
#   'software',
#   'architectural',
#   'building',
#   'code',
#   'theory',
#   'material',
#   'selection',
#   'eg',
#   'sketchup',
#   'client',
#   'budget',
#   'focus',
#   'select',
#   'finish',
#   'furnishing',
#   'scheme',
#   'create',
#   'concept',
#   'mood',
#   'board',
#   'contractor',
#   'drafting',
#   'autocad',
#   'modeling',
#   'blueprint',
#   'reading',
#   'detailoriente',
#   'prepare',
#   'detailed',
#   'drawing',
#   'plan',
#   'computeraide',
#   'assist',
#   'project'],
#  'Electrical Engineer': ['system',
#   'control',
#   'electronic',
#   'analysis',
#   'circuit',
#   'troubleshoot',
#   'electrical',
#   'power',
#   'energy',
#   'implement',
#   'automation',
#   'pcb',
#   'layout',
#   'embed',
#   'hardware',
#   'component',
#   'application',
#   'conduct',
#   'testing',
#   'validation',
#   'crossfunctional',
#   'team',
#   'development',
#   'engineering',
#   'renewable',
#   'safety',
#   'regulation',
#   'transmission',
#   'distribution',
#   'network',
#   'perform',
#   'flow',
#   'grid',
#   'reliability',
#   'efficiency',
#   'solution',
#   'plc',
#   'instrumentation',
#   'industrial',
#   'robotic'],
#  'Account Manager': ['client',
#   'account',
#   'sale',
#   'skill',
#   'relationship',
#   'communication',
#   'negotiation',
#   'closing',
#   'manage',
#   'revenue',
#   'growth',
#   'crossselle',
#   'upselle',
#   'forecast',
#   'customer',
#   'service',
#   'nurture',
#   'strong',
#   'understand',
#   'need',
#   'objective',
#   'serve',
#   'main',
#   'point',
#   'contact'],
#  'Purchasing Agent': ['demand',
#   'stock',
#   'skill',
#   'supplier',
#   'vendor',
#   'communication',
#   'coordination',
#   'coordinate',
#   'activity',
#   'distribution',
#   'partner',
#   'improve',
#   'efficiency',
#   'control',
#   'forecasting',
#   'analysis',
#   'manage',
#   'minimize',
#   'carry',
#   'cost',
#   'conduct',
#   'audits',
#   'reconcile',
#   'discrepancy',
#   'contract',
#   'negotiation',
#   'analytical',
#   'procure',
#   'good',
#   'service',
#   'organization',
#   'follow',
#   'procurement',
#   'policy',
#   'procedure',
#   'evaluate',
#   'bid',
#   'negotiate',
#   'relationship'],
#  'Customer Service Manager': ['customer',
#   'quality',
#   'team',
#   'feedback',
#   'support',
#   'issue',
#   'resolution',
#   'service',
#   'improvement',
#   'standard',
#   'metric',
#   'satisfaction',
#   'analysis',
#   'experience',
#   'journey',
#   'leadership',
#   'development',
#   'oversee',
#   'hire',
#   'set',
#   'kpis',
#   'target',
#   'handle',
#   'escalate',
#   'assurance',
#   'control',
#   'audit',
#   'procedure',
#   'compliance',
#   'root',
#   'cause',
#   'consistency',
#   'define',
#   'implement',
#   'qa',
#   'conduct',
#   'regular',
#   'audits',
#   'area',
#   'mapping'],
#  'SEM Specialist': ['ad',
#   'sem',
#   'marketing',
#   'campaign',
#   'analysis',
#   'search',
#   'engine',
#   'google',
#   'keyword',
#   'bing',
#   'spend',
#   'ppc',
#   'optimization',
#   'advertising',
#   'development',
#   'bid',
#   'insight',
#   'improve',
#   'stay',
#   'uptodate',
#   'change',
#   'good',
#   'practice',
#   'seo',
#   'digital',
#   'skill',
#   'plan',
#   'execute',
#   'conduct',
#   'metric',
#   'copywriting',
#   'ab',
#   'testing',
#   'conversion',
#   'tracking',
#   'manage',
#   'pay',
#   'platform',
#   'social',
#   'medium'],
#  'Nurse Manager': ['nursing',
#   'healthcare',
#   'staff',
#   'patient',
#   'care',
#   'skill',
#   'clinical',
#   'compliance',
#   'regulation',
#   'quality',
#   'procedure',
#   'assessment',
#   'development',
#   'communication',
#   'medical',
#   'education',
#   'curriculum',
#   'coordination',
#   'supervision',
#   'improvement',
#   'leadership',
#   'oversee',
#   'operation',
#   'setting',
#   'policy',
#   'protocol',
#   'ability',
#   'manage',
#   'team',
#   'hospital',
#   'facility',
#   'supervise',
#   'treatment',
#   'plan',
#   'outcome',
#   'instruction',
#   'educational',
#   'educate',
#   'train',
#   'good'],
#  'Legal Counsel': ['law',
#   'legal',
#   'trademark',
#   'ip',
#   'dispute',
#   'employment',
#   'compliance',
#   'contract',
#   'negotiation',
#   'intellectual',
#   'property',
#   'patent',
#   'copyright',
#   'conduct',
#   'regulation',
#   'agreement',
#   'matter',
#   'corporate',
#   'portfolio',
#   'litigation',
#   'resolution',
#   'protect',
#   'manage',
#   'right',
#   'diligence',
#   'search',
#   'handle',
#   'enforcement',
#   'workplace',
#   'discrimination',
#   'harassment',
#   'client',
#   'representation',
#   'advocacy',
#   'advise',
#   'labor',
#   'relation',
#   'hr',
#   'policy',
#   'employee'],
#  'Legal Secretary': ['legal',
#   'court',
#   'document',
#   'skill',
#   'attention',
#   'detail',
#   'record',
#   'manage',
#   'procedure',
#   'computer',
#   'literacy',
#   'organization',
#   'assist',
#   'judge',
#   'attorney',
#   'proceeding',
#   'information',
#   'public',
#   'prepare',
#   'distribute',
#   'order',
#   'courtroom',
#   'operation',
#   'run',
#   'smoothly',
#   'draft',
#   'communication',
#   'software',
#   'proficiency',
#   'administrative',
#   'support',
#   'professional',
#   'preparation',
#   'filing',
#   'file',
#   'schedule',
#   'appointment',
#   'calendar'],
#  'Electrical Designer': ['lighting',
#   'pcb',
#   'proficiency',
#   'system',
#   'circuit',
#   'electrical',
#   'software',
#   'create',
#   'layout',
#   'electronic',
#   'architectural',
#   'creative',
#   'concept',
#   'technical',
#   'specialize',
#   'plan',
#   'interior',
#   'exterior',
#   'select',
#   'fixture',
#   'enhance',
#   'visual',
#   'appeal',
#   'energy',
#   'efficiency',
#   'light',
#   'electronics',
#   'quality',
#   'control',
#   'print',
#   'board',
#   'device',
#   'schematic',
#   'manufacturability',
#   'engineering',
#   'autocad',
#   'component',
#   'building',
#   'infrastructure',
#   'project'],
#  'Physician Assistant': ['care',
#   'patient',
#   'medical',
#   'surgical',
#   'emergency',
#   'operating',
#   'room',
#   'team',
#   'assessment',
#   'condition',
#   'order',
#   'test',
#   'triage',
#   'procedure',
#   'technique',
#   'protocol',
#   'anesthesia',
#   'assist',
#   'surgeon',
#   'preoperative',
#   'postoperative',
#   'suture',
#   'wound',
#   'support',
#   'clinical',
#   'skill',
#   'communication',
#   'empathy',
#   'primary',
#   'healthcare',
#   'service',
#   'diagnose',
#   'treat',
#   'common',
#   'conduct',
#   'physical',
#   'examination',
#   'diagnostic',
#   'educate',
#   'health'],
#  'UX/UI Designer': ['user',
#   'interaction',
#   'principle',
#   'tool',
#   'create',
#   'interface',
#   'ui',
#   'wireframe',
#   'prototype',
#   'digital',
#   'usability',
#   'testing',
#   'eg',
#   'adobe',
#   'behavior',
#   'psychology',
#   'wireframing',
#   'prototyping',
#   'animation',
#   'microinteraction',
#   'collaborative',
#   'work',
#   'define',
#   'interact',
#   'seamless',
#   'journey',
#   'illustrate',
#   'developer',
#   'implement',
#   'usercentered',
#   'uxui',
#   'sketch',
#   'xd',
#   'information',
#   'architecture',
#   'flow',
#   'improve',
#   'experience',
#   'ux',
#   'intuitive'],
#  'Mechanical Engineer': ['manufacturing',
#   'hvac',
#   'lean',
#   'principle',
#   'quality',
#   'control',
#   'production',
#   'system',
#   'proficiency',
#   'software',
#   'mechanical',
#   'engineering',
#   'cadcam',
#   'assurance',
#   'sigma',
#   'certification',
#   'improve',
#   'efficiency',
#   'team',
#   'implement',
#   'workflow',
#   'autocad',
#   'analysis',
#   'equipment',
#   'skill',
#   'ability',
#   'installation',
#   'expertise',
#   'specialize',
#   'heating',
#   'ventilation',
#   'air',
#   'conditioning',
#   'calculate',
#   'requirement',
#   'energyefficient',
#   'compliance',
#   'standard',
#   'cad',
#   'eg'],
#  'Procurement Manager': ['supplier',
#   'procurement',
#   'analysis',
#   'assessment',
#   'skill',
#   'contract',
#   'vendor',
#   'relationship',
#   'attention',
#   'communication',
#   'negotiation',
#   'detail',
#   'diversity',
#   'purchase',
#   'order',
#   'spend',
#   'financial',
#   'acuman',
#   'support',
#   'decisionmake',
#   'conduct',
#   'assist',
#   'forecasting',
#   'strategic',
#   'inclusion',
#   'source',
#   'cost',
#   'initiative',
#   'selection',
#   'thinking',
#   'manage',
#   'negotiate',
#   'term',
#   'program',
#   'certification',
#   'collection',
#   'outreach',
#   'engagement',
#   'principle',
#   'promote'],
#  'Substance Abuse Counselor': ['family',
#   'support',
#   'counseling',
#   'therapy',
#   'individual',
#   'substance',
#   'abuse',
#   'treatment',
#   'skill',
#   'recovery',
#   'relapse',
#   'prevention',
#   'addiction',
#   'marriage',
#   'conflict',
#   'resolution',
#   'work',
#   'face',
#   'challenge',
#   'education',
#   'improve',
#   'dynamic',
#   'network',
#   'team',
#   'motivational',
#   'interview',
#   'offer',
#   'ongoing',
#   'guidance',
#   'assist',
#   'cope',
#   'foster',
#   'supportive',
#   'empathetic',
#   'relationship',
#   'technique',
#   'ethic',
#   'struggle',
#   'issue',
#   'conduct'],
#  'Front-End Developer': ['user',
#   'web',
#   'testing',
#   'ui',
#   'experience',
#   'ux',
#   'eg',
#   'html',
#   'css',
#   'collaboration',
#   'attention',
#   'detail',
#   'interface',
#   'responsive',
#   'wcag',
#   'disability',
#   'usability',
#   'implement',
#   'application',
#   'principle',
#   'website',
#   'create',
#   'graphic',
#   'visual',
#   'typography',
#   'color',
#   'standard',
#   'assistive',
#   'tool',
#   'aria',
#   'accessible',
#   'rich',
#   'internet',
#   'individual',
#   'guideline',
#   'feature',
#   'conduct',
#   'remediation',
#   'prototype',
#   'wireframe'],
#  'Environmental Engineer': ['environmental',
#   'sustainability',
#   'assessment',
#   'compliance',
#   'impact',
#   'plan',
#   'practice',
#   'regulatory',
#   'analysis',
#   'expertise',
#   'regulation',
#   'conduct',
#   'implement',
#   'system',
#   'green',
#   'certification',
#   'promote',
#   'organization',
#   'initiative',
#   'metric',
#   'goal'],
#  'Database Administrator': ['database',
#   'security',
#   'query',
#   'sql',
#   'regulation',
#   'implement',
#   'measure',
#   'access',
#   'compliance',
#   'development',
#   'modeling',
#   'language',
#   'eg',
#   'java',
#   'python',
#   'privacy',
#   'system',
#   'table',
#   'structure',
#   'script',
#   'integrity',
#   'backup',
#   'procedure',
#   'encryption',
#   'control',
#   'vulnerability',
#   'assessment',
#   'auditing',
#   'protect',
#   'unauthorized',
#   'cyber',
#   'threat',
#   'audit',
#   'activity',
#   'protection',
#   'analysis',
#   'visualization',
#   'proficiency',
#   'quality',
#   'assurance'],
#  'Marketing Analyst': ['marketing',
#   'tool',
#   'analysis',
#   'insight',
#   'eg',
#   'visualization',
#   'communication',
#   'attention',
#   'detail',
#   'campaign',
#   'digital',
#   'sql',
#   'python',
#   'tableau',
#   'power',
#   'bi',
#   'statistical',
#   'cleansing',
#   'transformation',
#   'acuman',
#   'measure',
#   'roi',
#   'adjustment',
#   'create',
#   'dashboard',
#   'seo',
#   'social',
#   'medium',
#   'sem',
#   'email',
#   'interpretation',
#   'automation',
#   'ab',
#   'test',
#   'skill',
#   'focus',
#   'website',
#   'traffic',
#   'metric',
#   'base'],
#  'Data Entry Clerk': ['record',
#   'office',
#   'administrative',
#   'task',
#   'file',
#   'organize',
#   'communication',
#   'organization',
#   'support',
#   'manage',
#   'document',
#   'assist',
#   'coordinate',
#   'schedule',
#   'handle',
#   'phone',
#   'call',
#   'correspondence',
#   'entry',
#   'retrieval',
#   'attention',
#   'detail',
#   'documentation',
#   'manner',
#   'compliance',
#   'recordkeeping',
#   'policy',
#   'regulation',
#   'retrieve',
#   'update',
#   'need'],
#  'Research Analyst': ['analysis',
#   'statistical',
#   'eg',
#   'behavior',
#   'skill',
#   'visualization',
#   'consumer',
#   'software',
#   'write',
#   'communication',
#   'social',
#   'methodology',
#   'collection',
#   'attention',
#   'detail',
#   'insight',
#   'survey',
#   'conduct',
#   'finding',
#   'science',
#   'spss',
#   'sas',
#   'gather',
#   'actionable',
#   'prepare',
#   'presentation',
#   'critical',
#   'thinking',
#   'technique',
#   'interpretation',
#   'r',
#   'python',
#   'tool',
#   'tableau',
#   'power',
#   'bi',
#   'focus',
#   'mining',
#   'dataset',
#   'method'],
#  'Quality Assurance Analyst': ['test',
#   'testing',
#   'qa',
#   'continuous',
#   'team',
#   'quality',
#   'case',
#   'defect',
#   'issue',
#   'automation',
#   'tool',
#   'eg',
#   'regression',
#   'development',
#   'compliance',
#   'improvement',
#   'standard',
#   'conduct',
#   'framework',
#   'script',
#   'execution',
#   'tracking',
#   'selenium',
#   'appium',
#   'execute',
#   'plan',
#   'software',
#   'document',
#   'bugs',
#   'error',
#   'anomaly',
#   'resolve',
#   'assurance',
#   'methodology',
#   'metric',
#   'kpi',
#   'audit',
#   'leadership',
#   'initiative',
#   'lead'],
#  'Civil Engineer': ['water',
#   'resource',
#   'structural',
#   'project',
#   'engineering',
#   'system',
#   'software',
#   'assessment',
#   'infrastructure',
#   'environmental',
#   'impact',
#   'manage',
#   'building',
#   'code',
#   'standard',
#   'hydrology',
#   'hydraulic',
#   'modeling',
#   'watershe',
#   'focus',
#   'waterrelate',
#   'flood',
#   'control',
#   'wastewater',
#   'treatment',
#   'address',
#   'quality',
#   'conservation',
#   'issue',
#   'analysis',
#   'eg',
#   'autocad',
#   'traffic',
#   'plan',
#   'civil',
#   'principle',
#   'integrity',
#   'component',
#   'safety',
#   'compliance'],
#  'Systems Administrator': ['database',
#   'software',
#   'security',
#   'backup',
#   'system',
#   'technical',
#   'hardware',
#   'support',
#   'eg',
#   'mysql',
#   'oracle',
#   'sql',
#   'server',
#   'tuning',
#   'optimization',
#   'recovery',
#   'administer',
#   'restore',
#   'implement',
#   'access',
#   'control',
#   'troubleshooting',
#   'customer',
#   'service',
#   'communication',
#   'enduser',
#   'troubleshoot',
#   'issue',
#   'resolve',
#   'itrelate',
#   'problem',
#   'install',
#   'configure',
#   'computer',
#   'documentation',
#   'base'],
#  'Software Engineer': ['eg',
#   'deployment',
#   'frontend',
#   'web',
#   'python',
#   'backend',
#   'language',
#   'java',
#   'nodejs',
#   'database',
#   'security',
#   'proficiency',
#   'framework',
#   'like',
#   'implement',
#   'html',
#   'css',
#   'javascript',
#   'experience',
#   'application',
#   'development',
#   'continuous',
#   'cicd',
#   'ruby',
#   'api',
#   'sql',
#   'nosql',
#   'server',
#   'good',
#   'practice',
#   'express',
#   'django',
#   'serverside',
#   'logic',
#   'integrity',
#   'apis',
#   'seamless',
#   'communication',
#   'react',
#   'angular'],
#  'Environmental Consultant': ['environmental',
#   'impact',
#   'assessment',
#   'sustainability',
#   'regulation',
#   'compliance',
#   'conduct',
#   'analysis',
#   'project',
#   'sustainable',
#   'practice',
#   'client',
#   'collection',
#   'gis',
#   'geographic',
#   'information',
#   'system',
#   'technical',
#   'writing',
#   'development',
#   'eia',
#   'mitigation',
#   'team',
#   'regulator',
#   'regulatory',
#   'requirement',
#   'auditing',
#   'law',
#   'audit',
#   'implement',
#   'consulting',
#   'green',
#   'building',
#   'standard',
#   'policy',
#   'communication',
#   'focus',
#   'initiative',
#   'advise',
#   'reduce'],
#  'Urban Planner': ['environmental',
#   'traffic',
#   'infrastructure',
#   'regulation',
#   'urban',
#   'public',
#   'project',
#   'impact',
#   'assessment',
#   'sustainability',
#   'gis',
#   'proficiency',
#   'address',
#   'zone',
#   'engineering',
#   'specialize',
#   'efficient',
#   'network',
#   'congestion',
#   'improve',
#   'transit',
#   'system',
#   'ecosystem',
#   'analysis',
#   'focus',
#   'sustainable',
#   'development',
#   'recommend',
#   'compliance',
#   'measure',
#   'promote',
#   'green',
#   'practice',
#   'community',
#   'engagement',
#   'plan',
#   'land',
#   'use',
#   'area',
#   'government'],
#  'Tax Consultant': ['tax',
#   'compliance',
#   'international',
#   'law',
#   'transfer',
#   'pricing',
#   'credit',
#   'client',
#   'relationship',
#   'communication',
#   'skill',
#   'software',
#   'proficiency',
#   'financial',
#   'return',
#   'crossborder',
#   'regulation',
#   'corporate',
#   'deduction',
#   'irs',
#   'assist',
#   'prepare',
#   'individual',
#   'treaty',
#   'agreement',
#   'foreign',
#   'documentation',
#   'multinational',
#   'specialize',
#   'issue',
#   'guidance',
#   'global',
#   'incentive',
#   'development',
#   'analysis',
#   'advise',
#   'statement',
#   'audits',
#   'negotiation',
#   'authority'],
#  'Marketing Manager': ['marketing',
#   'brand',
#   'analysis',
#   'plan',
#   'digital',
#   'campaign',
#   'message',
#   'launch',
#   'collaboration',
#   'create',
#   'team',
#   'seo',
#   'social',
#   'medium',
#   'email',
#   'eg',
#   'manage',
#   'identity',
#   'creative',
#   'material',
#   'position',
#   'collateral',
#   'creation',
#   'pricing',
#   'crossfunctional',
#   'promote',
#   'specific',
#   'service',
#   'sale',
#   'conduct',
#   'sem',
#   'content',
#   'web',
#   'google',
#   'analytics',
#   'automation',
#   'tool',
#   'hubspot',
#   'marketo',
#   'execute'],
#  'Social Media Manager': ['social',
#   'medium',
#   'insight',
#   'analysis',
#   'media',
#   'update',
#   'tool',
#   'eg',
#   'google',
#   'analytics',
#   'facebook',
#   'roi',
#   'measurement',
#   'identification',
#   'user',
#   'behavior',
#   'actionable',
#   'key',
#   'indicator',
#   'kpi',
#   'recommend',
#   'optimization',
#   'stay',
#   'change',
#   'content',
#   'platform',
#   'creation',
#   'engagement',
#   'community',
#   'online',
#   'marketing',
#   'development',
#   'advertising',
#   'target',
#   'datadriven',
#   'decisionmake',
#   'implement',
#   'increase',
#   'brand',
#   'awareness'],
#  'Business Development Manager': ['sale',
#   'partnership',
#   'development',
#   'goal',
#   'new',
#   'team',
#   'negotiation',
#   'collaboration',
#   'establish',
#   'strategic',
#   'alliance',
#   'negotiate',
#   'agreement',
#   'term',
#   'partner',
#   'achieve',
#   'mutual',
#   'expansion',
#   'execution',
#   'execute',
#   'plan',
#   'expand',
#   'presence',
#   'reach',
#   'customer',
#   'conduct',
#   'analysis',
#   'evaluate',
#   'leadership',
#   'lead',
#   'manage',
#   'set',
#   'target',
#   'client',
#   'relationship'],
#  'Marketing Coordinator': ['marketing',
#   'digital',
#   'content',
#   'event',
#   'social',
#   'medium',
#   'development',
#   'seo',
#   'proficiency',
#   'create',
#   'campaign',
#   'email',
#   'vendor',
#   'sponsor',
#   'promotion',
#   'analysis',
#   'creation',
#   'copywrite',
#   'automation',
#   'tool',
#   'assist',
#   'execution',
#   'collateral',
#   'metric',
#   'advertising',
#   'google',
#   'system',
#   'cms',
#   'support',
#   'effort',
#   'schedule',
#   'budgeting',
#   'financial',
#   'relation',
#   'publicity',
#   'coordination',
#   'skill',
#   'plan',
#   'coordinate',
#   'execute'],
#  'Art Director': ['art',
#   'visual',
#   'creative',
#   'graphic',
#   'brand',
#   'identity',
#   'concept',
#   'advertising',
#   'team',
#   'project',
#   'exhibition',
#   'collection',
#   'direction',
#   'typography',
#   'user',
#   'interface',
#   'ui',
#   'adobe',
#   'suite',
#   'proficiency',
#   'creation',
#   'create',
#   'medium',
#   'print',
#   'digital',
#   'campaign',
#   'use',
#   'software',
#   'tool',
#   'produce',
#   'highquality',
#   'execute',
#   'history',
#   'curation',
#   'cultural',
#   'awareness',
#   'curate',
#   'manage',
#   'gallery',
#   'select'],
#  'Event Coordinator': ['event',
#   'client',
#   'wedding',
#   'plan',
#   'vendor',
#   'budget',
#   'coordination',
#   'timeline',
#   'communication',
#   'creativity',
#   'attention',
#   'detail',
#   'venue',
#   'selection',
#   'marketing',
#   'corporate',
#   'negotiation',
#   'promotion',
#   'risk',
#   'organize',
#   'conference',
#   'party',
#   'coordinate',
#   'run',
#   'smoothly',
#   'meet',
#   'expectation',
#   'emotional',
#   'couple',
#   'manage',
#   'ceremony',
#   'reception',
#   'etiquette',
#   'intelligence',
#   'assist',
#   'execute',
#   'day',
#   'resolve',
#   'issue',
#   'arise'],
#  'Executive Assistant': ['office',
#   'expense',
#   'facility',
#   'vendor',
#   'relation',
#   'project',
#   'coordination',
#   'calendar',
#   'correspondence',
#   'travel',
#   'coordinate',
#   'administration',
#   'budgeting',
#   'tracking',
#   'team',
#   'supervision',
#   'supplier',
#   'oversee',
#   'operation',
#   'manage',
#   'budget',
#   'event',
#   'communication',
#   'time',
#   'organizational',
#   'skill',
#   'appointment',
#   'discretion',
#   'confidentiality',
#   'highlevel',
#   'administrative',
#   'support',
#   'executive',
#   'arrangement',
#   'prepare',
#   'presentation',
#   'act',
#   'gatekeeper',
#   'handle',
#   'confidential'],
#  'Investment Banker': ['investment',
#   'financial',
#   'analysis',
#   'client',
#   'portfolio',
#   'modeling',
#   'decision',
#   'create',
#   'projection',
#   'merger',
#   'acquisition',
#   'diligence',
#   'risk',
#   'assessment',
#   'manage',
#   'behalf',
#   'organization',
#   'adjust',
#   'regular',
#   'update',
#   'ma',
#   'expertise',
#   'valuation',
#   'technique',
#   'advise',
#   'corporate',
#   'finance',
#   'transaction',
#   'perform',
#   'negotiate',
#   'structure',
#   'deal'],
#  'Key Account Manager': ['account',
#   'client',
#   'relationship',
#   'sale',
#   'development',
#   'negotiation',
#   'skill',
#   'focus',
#   'strategic',
#   'key',
#   'longterm',
#   'goal',
#   'growth',
#   'crossfunctional',
#   'team',
#   'meet',
#   'need',
#   'profitability'],
#  'Network Administrator': ['security',
#   'network',
#   'system',
#   'attention',
#   'detail',
#   'server',
#   'technical',
#   'administration',
#   'communication',
#   'skill',
#   'intrusion',
#   'detection',
#   'firewall',
#   'policy',
#   'procedure',
#   'eg',
#   'troubleshoot',
#   'collaboration',
#   'maintenance',
#   'active',
#   'directory',
#   'backup',
#   'recovery',
#   'cloud',
#   'computing',
#   'aws',
#   'azure',
#   'good',
#   'practice',
#   'administer',
#   'uptime',
#   'reliability',
#   'perform',
#   'software',
#   'installation',
#   'update',
#   'support',
#   'enduser',
#   'protocols',
#   'prevention'],
#  'Teacher': ['student',
#   'education',
#   'plan',
#   'special',
#   'support',
#   'curriculum',
#   'classroom',
#   'instruction',
#   'need',
#   'assessment',
#   'development',
#   'individualized',
#   'iep',
#   'staff',
#   'expertise',
#   'subject',
#   'area',
#   'educational',
#   'teach',
#   'pedagogy',
#   'differentiate',
#   'deliver',
#   'engage',
#   'lesson',
#   'adapt',
#   'teaching',
#   'method',
#   'progress',
#   'feedback',
#   'create',
#   'positive',
#   'inclusive',
#   'environment',
#   'behavior',
#   'technique',
#   'collaboration',
#   'law',
#   'regulation',
#   'tailor',
#   'implement'],
#  'SEO Specialist': ['content',
#   'seo',
#   'optimization',
#   'website',
#   'keyword',
#   'technical',
#   'crawl',
#   'schema',
#   'markup',
#   'audits',
#   'search',
#   'engine',
#   'onpage',
#   'offpage',
#   'marketing',
#   'mapping',
#   'creator',
#   'align',
#   'goal',
#   'improvement',
#   'analysis',
#   'xml',
#   'sitemaps',
#   'canonicalization',
#   'resolve',
#   'issue',
#   'error',
#   'speed',
#   'mobilefriendliness',
#   'implement',
#   'structured',
#   'indexing',
#   'sitemap',
#   'accuracy',
#   'tool',
#   'eg',
#   'google',
#   'analytics',
#   'semrush',
#   'conduct'],
#  'Nurse Practitioner': ['care',
#   'health',
#   'assessment',
#   'patient',
#   'healthcare',
#   'critical',
#   'family',
#   'chronic',
#   'service',
#   'medication',
#   'medicine',
#   'diagnostic',
#   'test',
#   'manage',
#   'condition',
#   'nursing',
#   'treatment',
#   'acute',
#   'setting',
#   'medical',
#   'pediatric',
#   'disease',
#   'education',
#   'focus',
#   'familycentere',
#   'individual',
#   'age',
#   'perform',
#   'physical',
#   'exam',
#   'order',
#   'promote',
#   'wellness',
#   'promotion',
#   'administration',
#   'electronic',
#   'record',
#   'ehr',
#   'comprehensive',
#   'primary'],
#  'SEO Analyst': ['seo',
#   'content',
#   'optimization',
#   'technical',
#   'website',
#   'keyword',
#   'web',
#   'developer',
#   'improvement',
#   'audits',
#   'speed',
#   'search',
#   'engine',
#   'plan',
#   'execute',
#   'seofocuse',
#   'creator',
#   'enhancement',
#   'tool',
#   'eg',
#   'scream',
#   'frog',
#   'ahref',
#   'schema',
#   'markup',
#   'site',
#   'xml',
#   'sitemap',
#   'canonicalization',
#   'focus',
#   'aspect',
#   'structure',
#   'page',
#   'mobile',
#   'conduct',
#   'implementation'],
#  'Data Engineer': ['architecture',
#   'database',
#   'system',
#   'processing',
#   'sql',
#   'scripting',
#   'language',
#   'source',
#   'create',
#   'workflow',
#   'perform',
#   'validation',
#   'quality',
#   'check',
#   'modeling',
#   'meet',
#   'need',
#   'schema',
#   'security',
#   'compliance',
#   'etc',
#   'analysis',
#   'distribute',
#   'computing',
#   'work',
#   'complex',
#   'dataset',
#   'like',
#   'solution',
#   'storage'],
#  'Research Scientist': ['analysis',
#   'skill',
#   'proposal',
#   'project',
#   'literature',
#   'review',
#   'collection',
#   'tool',
#   'technique',
#   'survey',
#   'qualitative',
#   'quantitative',
#   'method',
#   'writing',
#   'presentation',
#   'collect',
#   'compile',
#   'source',
#   'assist',
#   'preparation',
#   'documentation',
#   'support',
#   'activity',
#   'validation',
#   'methodology',
#   'synthesis',
#   'statistical',
#   'software',
#   'eg',
#   'spss',
#   'r',
#   'development',
#   'strong',
#   'communication',
#   'plan',
#   'conduct',
#   'scientific',
#   'experimental',
#   'crossfunctional',
#   'team'],
#  'HR Coordinator': ['benefit',
#   'employee',
#   'program',
#   'material',
#   'system',
#   'assist',
#   'coordinate',
#   'record',
#   'recruitment',
#   'communication',
#   'coordination',
#   'development',
#   'learn',
#   'need',
#   'facilitate',
#   'session',
#   'workshop',
#   'candidate',
#   'applicant',
#   'administration',
#   'compliance',
#   'hris',
#   'administer',
#   'respond',
#   'inquiry',
#   'change',
#   'provider',
#   'broker',
#   'educate',
#   'available',
#   'screen',
#   'tracking',
#   'activity',
#   'post',
#   'job',
#   'opening',
#   'interview',
#   'manage',
#   'positive',
#   'experience'],
#  'Data Scientist': ['python',
#   'preprocesse',
#   'analysis',
#   'evaluate',
#   'eg',
#   'database'],
#  'Psychologist': ['psychological',
#   'assessment',
#   'skill',
#   'education',
#   'conduct',
#   'plan',
#   'counseling',
#   'individualized',
#   'psychology',
#   'support',
#   'methodology',
#   'analysis',
#   'study',
#   'write',
#   'critical',
#   'thinking',
#   'experiment',
#   'publish',
#   'finding',
#   'academic',
#   'journal',
#   'contribute',
#   'advancement',
#   'school',
#   'special',
#   'test',
#   'collaboration',
#   'work',
#   'educational',
#   'setting',
#   'student',
#   'emotional',
#   'wellbeing',
#   'educator',
#   'assist',
#   'development',
#   'clinical',
#   'tool',
#   'diagnostic',
#   'empathy'],
#  'Architect': ['building',
#   'architectural',
#   'sustainable',
#   'green',
#   'material',
#   'project',
#   'construction',
#   'client',
#   'principle',
#   'energy',
#   'efficiency',
#   'lee',
#   'certification',
#   'environmental',
#   'impact',
#   'assessment',
#   'focus',
#   'ecofriendly',
#   'practice',
#   'integrate',
#   'advise',
#   'energyefficient',
#   'solution',
#   'code',
#   'regulation',
#   'document',
#   'system',
#   'coordination',
#   'communication',
#   'lead',
#   'concept',
#   'supervision',
#   'engineer',
#   'contractor',
#   'timeline',
#   'budget',
#   'software',
#   'eg',
#   'autocad',
#   'revit'],
#  'Pediatrician': ['pediatric',
#   'care',
#   'patient',
#   'surgical',
#   'procedure',
#   'child',
#   'cardiology',
#   'injury',
#   'treatment',
#   'diagnose',
#   'treat',
#   'medical',
#   'surgery',
#   'operating',
#   'room',
#   'protocol',
#   'technique',
#   'anesthesia',
#   'perform',
#   'congenital',
#   'abnormality',
#   'coordinate',
#   'preoperative',
#   'postoperative',
#   'wellbeing',
#   'recovery',
#   'young',
#   'specialization',
#   'advance',
#   'subspecialty',
#   'eg',
#   'oncology',
#   'diagnostic',
#   'specialize',
#   'specific',
#   'area',
#   'medicine',
#   'neurology',
#   'complex',
#   'condition'],
#  'Systems Analyst': ['system',
#   'analysis',
#   'requirement',
#   'solution',
#   'gather',
#   'improvement',
#   'focus',
#   'improve',
#   'conduct',
#   'workflow',
#   'facilitate',
#   'communication',
#   'stakeholder',
#   'troubleshoot',
#   'support',
#   'documentation',
#   'specification',
#   'document',
#   'team',
#   'implement'],
#  'Supply Chain Manager': ['demand',
#   'forecast',
#   'sale',
#   'operation',
#   'team',
#   'analysis',
#   'sop',
#   'erp',
#   'software',
#   'proficiency',
#   'pattern',
#   'production',
#   'implement',
#   'forecasting',
#   'tool',
#   'control',
#   'vendor',
#   'relation',
#   'leadership',
#   'manage',
#   'distribution',
#   'good',
#   'efficiency',
#   'reduce',
#   'cost',
#   'minimize',
#   'delivery',
#   'time'],
#  'Software Architect': ['cloud',
#   'architecture',
#   'solution',
#   'software',
#   'enterprise',
#   'technical',
#   'development',
#   'security',
#   'alignment',
#   'governance',
#   'compliance',
#   'focus',
#   'align',
#   'overall',
#   'scalability',
#   'interoperability',
#   'evaluate',
#   'recommend',
#   'stack',
#   'tool',
#   'computing',
#   'highlevel',
#   'project',
#   'define',
#   'requirement',
#   'specification',
#   'guidance',
#   'team',
#   'good',
#   'practice',
#   'compute',
#   'platform',
#   'aws',
#   'azure',
#   'etc',
#   'containerization',
#   'docker',
#   'kubernete',
#   'implement',
#   'cloudbase'],
#  'Customer Success Manager': ['customer',
#   'client',
#   'need',
#   'service',
#   'relationship',
#   'communication',
#   'skill',
#   'ticket',
#   'system',
#   'usage',
#   'responsive',
#   'effective',
#   'support',
#   'addressing',
#   'inquiry',
#   'resolve',
#   'issue',
#   'escalate',
#   'case',
#   'document',
#   'interaction',
#   'feedback',
#   'development',
#   'onboarding',
#   'new',
#   'employee',
#   'account',
#   'sale',
#   'negotiation',
#   'analysis',
#   'nurture',
#   'key',
#   'understand',
#   'goal',
#   'upselle',
#   'crossselle',
#   'satisfaction',
#   'retention',
#   'orientation',
#   'hr'],
#  'Operations Manager': ['quality',
#   'control',
#   'operation',
#   'analysis',
#   'procurement',
#   'supplier',
#   'relationship',
#   'team',
#   'manage',
#   'implement',
#   'improvement',
#   'forecasting',
#   'risk',
#   'assessment',
#   'mitigation',
#   'costeffectiveness',
#   'timely',
#   'delivery',
#   'methodology',
#   'statistical',
#   'spc',
#   'root',
#   'cause',
#   'corrective',
#   'action',
#   'system',
#   'eg',
#   'iso',
#   'compliance',
#   'regulatory',
#   'establish',
#   'enforce',
#   'standard',
#   'procedure',
#   'conduct',
#   'audit',
#   'inspection',
#   'production',
#   'address',
#   'issue'],
#  'Digital Marketing Specialist': ['social',
#   'seo',
#   'content',
#   'medium',
#   'search',
#   'metric',
#   'email',
#   'eg',
#   'media',
#   'community',
#   'engagement',
#   'online',
#   'engine',
#   'keyword',
#   'optimization',
#   'platform',
#   'creation',
#   'create',
#   'analysis',
#   'facebook',
#   'twitter',
#   'instagram',
#   'schedule',
#   'insight',
#   'pay',
#   'advertising',
#   'manage',
#   'grow',
#   'account',
#   'engage',
#   'interact',
#   'calendar',
#   'campaign',
#   'rank',
#   'factor',
#   'onpage',
#   'offpage',
#   'tool',
#   'google',
#   'analytics'],
#  'Occupational Therapist': ['therapy',
#   'assessment',
#   'skill',
#   'occupational',
#   'pediatric',
#   'technique',
#   'care',
#   'intervention',
#   'mental',
#   'health',
#   'assistive',
#   'healthcare',
#   'communication',
#   'challenge',
#   'child',
#   'developmental',
#   'sensory',
#   'individualized',
#   'plan',
#   'help',
#   'conduct',
#   'treatment',
#   'geriatric',
#   'geriatricspecific',
#   'agingrelate',
#   'condition',
#   'eg',
#   'dementia',
#   'arthritis',
#   'fall',
#   'prevention',
#   'coordination',
#   'team',
#   'senior',
#   'patient',
#   'advocacy',
#   'empathy',
#   'compassion',
#   'focus',
#   'old'],
#  'Software Tester': ['test',
#   'development',
#   'eg',
#   'quality',
#   'case',
#   'script',
#   'automate',
#   'regression',
#   'testing',
#   'tool',
#   'methodology',
#   'software',
#   'system',
#   'automation',
#   'framework',
#   'continuous',
#   'assurance',
#   'manual',
#   'bug',
#   'tracking',
#   'application',
#   'defect',
#   'create',
#   'plan',
#   'team',
#   'resolve',
#   'issue',
#   'bottleneck',
#   'selenium',
#   'appium',
#   'scripting',
#   'language',
#   'python',
#   'java',
#   'implement',
#   'write',
#   'result',
#   'feedback',
#   'improvement',
#   'jmeter'],
#  'Brand Ambassador': ['brand',
#   'skill',
#   'communication',
#   'promotional',
#   'sale',
#   'technique',
#   'event',
#   'demonstrate',
#   'customer',
#   'marketing',
#   'engagement',
#   'social',
#   'medium',
#   'content',
#   'promotion',
#   'represent',
#   'promote',
#   'trade',
#   'show',
#   'campaign',
#   'engage',
#   'consumer',
#   'educate',
#   'service',
#   'distribute',
#   'material',
#   'showcase',
#   'retail',
#   'location',
#   'highlight',
#   'feature',
#   'benefit',
#   'attract',
#   'potential',
#   'answer',
#   'question',
#   'encourage',
#   'trial',
#   'creation',
#   'audience'],
#  'Administrative Assistant': ['communication',
#   'skill',
#   'travel',
#   'meeting',
#   'office',
#   'organization',
#   'time',
#   'attention',
#   'detail',
#   'proficiency',
#   'eg',
#   'database',
#   'verification',
#   'calendar',
#   'coordination',
#   'scheduling',
#   'correspondence',
#   'confidentiality',
#   'ms',
#   'highlevel',
#   'administrative',
#   'support',
#   'executive',
#   'manage',
#   'schedule',
#   'coordinate',
#   'arrangement',
#   'handle',
#   'confidential',
#   'information',
#   'discretion',
#   'entry',
#   'accuracy',
#   'speed',
#   'software',
#   'microsoft',
#   'access',
#   'excel',
#   'multitaske',
#   'keyboarding'],
#  'Content Writer': ['content',
#   'marketing',
#   'technical',
#   'plan',
#   'seo',
#   'optimization',
#   'documentation',
#   'user',
#   'manual',
#   'editorial',
#   'calendar',
#   'align',
#   'brand',
#   'objective',
#   'adjust',
#   'edit',
#   'writing',
#   'skill',
#   'write',
#   'instructional',
#   'guide',
#   'translate',
#   'complex',
#   'information',
#   'userfriendly',
#   'subject',
#   'matter',
#   'expert',
#   'engineer',
#   'copywrite',
#   'creation',
#   'creativity',
#   'create',
#   'engage',
#   'persuasive',
#   'material',
#   'website',
#   'blog',
#   'post',
#   'social'],
#  'Web Developer': ['user',
#   'web',
#   'database',
#   'application',
#   'frontend',
#   'eg',
#   'backend',
#   'development',
#   'apis',
#   'serverside',
#   'experience',
#   'ux',
#   'api',
#   'work',
#   'aspect',
#   'create',
#   'fullstack',
#   'solution',
#   'integrate',
#   'thirdparty',
#   'service',
#   'troubleshoot',
#   'debug',
#   'nodejs',
#   'python',
#   'sql',
#   'mongodb',
#   'logic',
#   'support',
#   'security',
#   'implement',
#   'restful',
#   'retrieval',
#   'manipulation',
#   'html',
#   'css',
#   'javascript',
#   'framework',
#   'react',
#   'angular'],
#  'Landscape Designer': ['sustainable',
#   'landscape',
#   'plant',
#   'project',
#   'native',
#   'practice',
#   'selection',
#   'water',
#   'conservation',
#   'soil',
#   'health',
#   'green',
#   'building',
#   'lee',
#   'certification',
#   'focus',
#   'environmentally',
#   'friendly',
#   'incorporate',
#   'rainwater',
#   'harvesting',
#   'ecological',
#   'principle',
#   'educate',
#   'client',
#   'landscaping',
#   'benefit',
#   'architecture',
#   'site',
#   'environmental',
#   'sustainability',
#   'autocad',
#   'plan',
#   'outdoor',
#   'space',
#   'commercial',
#   'public',
#   'park',
#   'resort',
#   'urban'],
#  'QA Engineer': ['quality',
#   'improvement',
#   'team',
#   'qa',
#   'test',
#   'assurance',
#   'leadership',
#   'control',
#   'lead',
#   'manage',
#   'plan',
#   'resource',
#   'allocation',
#   'development',
#   'define',
#   'standard',
#   'metric',
#   'oversee',
#   'continuous',
#   'effort'],
#  'Physical Therapist': ['rehabilitation',
#   'developmental',
#   'child',
#   'improve',
#   'mobility',
#   'fall',
#   'prevention',
#   'elderly',
#   'assessment',
#   'therapy',
#   'patient',
#   'program',
#   'treatment',
#   'exercise',
#   'pediatric',
#   'psychology',
#   'work',
#   'physical',
#   'disability',
#   'motor',
#   'skill',
#   'parent',
#   'caregiver',
#   'geriatric',
#   'care',
#   'focus',
#   'population',
#   'address',
#   'agerelate',
#   'pain',
#   'issue',
#   'create',
#   'overall',
#   'functional',
#   'independence',
#   'orthopedic',
#   'education',
#   'specialize',
#   'treat',
#   'musculoskeletal'],
#  'Sales Representative': ['sale',
#   'client',
#   'relationship',
#   'presentation',
#   'contract',
#   'lead',
#   'customer',
#   'negotiation',
#   'service',
#   'account',
#   'solution',
#   'sell',
#   'prospect',
#   'building',
#   'conduct',
#   'negotiate',
#   'meet',
#   'generation',
#   'communication',
#   'crm',
#   'software',
#   'eg',
#   'salesforce',
#   'closing',
#   'technique',
#   'qualify',
#   'close',
#   'deal',
#   'phone',
#   'email',
#   'accurate',
#   'record',
#   'excellent',
#   'forecasting',
#   'metric',
#   'manage',
#   'achieve',
#   'revenue',
#   'target',
#   'ongoing'],
#  'Inventory Analyst': ['stock',
#   'control',
#   'demand',
#   'forecast',
#   'tracking',
#   'system',
#   'coordination',
#   'skill',
#   'manage',
#   'movement',
#   'turnover',
#   'conduct',
#   'regular',
#   'count',
#   'reconcile',
#   'discrepancy',
#   'accurate',
#   'efficient'],
#  'Family Lawyer': ['mediation',
#   'child',
#   'case',
#   'legal',
#   'resolution',
#   'custody',
#   'law',
#   'court',
#   'negotiation',
#   'client',
#   'neutrality',
#   'family',
#   'advocacy',
#   'representation',
#   'counseling',
#   'preparation',
#   'specialize',
#   'advocate',
#   'good',
#   'interest',
#   'conduct',
#   'investigation',
#   'gather',
#   'evidence',
#   'present',
#   'negotiate',
#   'parenting',
#   'plan',
#   'visitation',
#   'schedule',
#   'conflict',
#   'communication',
#   'skill',
#   'technique',
#   'facilitate',
#   'alternative',
#   'dispute',
#   'adr',
#   'help',
#   'reach'],
#  'Market Research Analyst': ['analysis',
#   'collection',
#   'project',
#   'methodology',
#   'consumer',
#   'behavior',
#   'service',
#   'improvement',
#   'interpret',
#   'qualitative',
#   'quantitative',
#   'coordination',
#   'survey',
#   'administration',
#   'coordinate',
#   'participant',
#   'recruitment',
#   'team',
#   'timeline',
#   'meet',
#   'database',
#   'record'],
#  'Legal Assistant': ['legal',
#   'document',
#   'case',
#   'communication',
#   'eg',
#   'preparation',
#   'support',
#   'attention',
#   'detail',
#   'skill',
#   'database',
#   'client',
#   'file',
#   'software',
#   'proficiency',
#   'administrative',
#   'calendar',
#   'drafting',
#   'efile',
#   'lexisnexis',
#   'deposition',
#   'trial',
#   'ethic',
#   'confidentiality',
#   'assist',
#   'lawyer',
#   'draft',
#   'pleading',
#   'organize',
#   'manage',
#   'ediscovery',
#   'review',
#   'litigation',
#   'team',
#   'electronic',
#   'task',
#   'docket',
#   'transcription',
#   'organization',
#   'court'],
#  'Product Designer': ['industrial',
#   'principle',
#   'cad',
#   'modeling',
#   'prototyping',
#   'testing',
#   'focus',
#   'physical',
#   'aesthetic',
#   'concept',
#   'sketch',
#   'engineer',
#   'feasibility'],
#  'Office Manager': ['office',
#   'manage',
#   'facility',
#   'maintenance',
#   'space',
#   'safety',
#   'compliance',
#   'vendor',
#   'budget',
#   'oversee',
#   'improvement',
#   'communication',
#   'skill',
#   'administrative',
#   'staff',
#   'property',
#   'health',
#   'workplace',
#   'renovation',
#   'administration',
#   'calendar',
#   'reception',
#   'dutie',
#   'record',
#   'keep',
#   'coordinate',
#   'activity',
#   'workflow',
#   'assist',
#   'document',
#   'filing',
#   'relationship',
#   'leadership',
#   'supervision',
#   'budgeting',
#   'financial',
#   'operation',
#   'policy',
#   'procedure',
#   'resource'],
#  'Financial Controller': ['financial',
#   'accounting',
#   'account',
#   'audits',
#   'tax',
#   'analysis',
#   'software',
#   'eg',
#   'compliance',
#   'budget',
#   'sap',
#   'oracle',
#   'gaap',
#   'generally',
#   'accept',
#   'principle',
#   'manage',
#   'function',
#   'payable',
#   'receivable',
#   'payroll',
#   'statement',
#   'preparation',
#   'conduct',
#   'forecasting',
#   'coordinate',
#   'filing',
#   'risk',
#   'excel',
#   'quickbooks',
#   'strategic',
#   'oversee',
#   'operation',
#   'cash',
#   'flow',
#   'standard',
#   'regulation',
#   'supervise',
#   'finance',
#   'staff'],
#  'Procurement Specialist': ['procurement',
#   'supplier',
#   'negotiation',
#   'vendor',
#   'analysis',
#   'cost',
#   'manage',
#   'relationship',
#   'initiative',
#   'timely',
#   'delivery',
#   'good',
#   'service',
#   'purchase',
#   'order',
#   'communication',
#   'source',
#   'contract',
#   'control',
#   'support',
#   'activity',
#   'documentation',
#   'record',
#   'assist',
#   'audit',
#   'assessment',
#   'evaluate',
#   'potential',
#   'negotiate',
#   'term'],
#  'Customer Service Representative': ['customer',
#   'chat',
#   'live',
#   'support',
#   'service',
#   'center',
#   'operation',
#   'skill',
#   'handle',
#   'incoming',
#   'phone',
#   'call',
#   'information',
#   'assistance',
#   'follow',
#   'script',
#   'procedure',
#   'document',
#   'detail',
#   'online',
#   'communication',
#   'problem',
#   'resolution',
#   'offer',
#   'realtime',
#   'message',
#   'platform',
#   'respond',
#   'inquiry',
#   'promptly',
#   'accurately',
#   'multitask',
#   'manage',
#   'queue'],
#  'Front-End Engineer': ['frontend',
#   'web',
#   'user',
#   'javascript',
#   'framework',
#   'react',
#   'angular',
#   'development',
#   'interface',
#   'eg',
#   'dom',
#   'manipulation',
#   'ajax',
#   'debugging',
#   'troubleshoot',
#   'interactive',
#   'application',
#   'library',
#   'debug',
#   'resolve',
#   'issue',
#   'crossbrowser',
#   'compatibility',
#   'uiux',
#   'wireframing',
#   'prototype',
#   'standard',
#   'responsive',
#   'collaboration',
#   'skill',
#   'focus',
#   'ui',
#   'experience',
#   'ux',
#   'translate',
#   'mockup',
#   'functional',
#   'conduct',
#   'usability',
#   'testing'],
#  'Copywriter': ['seo',
#   'content',
#   'technical',
#   'optimization',
#   'brand',
#   'search',
#   'engine',
#   'keyword',
#   'onpage',
#   'meta',
#   'tag',
#   'documentation',
#   'user',
#   'manual',
#   'write',
#   'writing',
#   'creative',
#   'advertising',
#   'copy',
#   'storytelling',
#   'marketing',
#   'campaign',
#   'seofriendly',
#   'tool',
#   'eg',
#   'semrush',
#   'web',
#   'blog',
#   'post',
#   'description',
#   'conduct',
#   'ranking',
#   'traffic',
#   'specification',
#   'industryspecific',
#   'terminology',
#   'skill',
#   'create',
#   'guide',
#   'translate'],
#  'Interior Designer': ['interior',
#   'selection',
#   'furniture',
#   'space',
#   'hospitality',
#   'hotel',
#   'experience',
#   'select',
#   'create',
#   'residential',
#   'color',
#   'material',
#   'plan',
#   'restaurant',
#   'commercial',
#   'building',
#   'code',
#   'regulation',
#   'brand',
#   'theme',
#   'ffe',
#   'fixture',
#   'equipment',
#   'customer',
#   'specialize',
#   'resort',
#   'establishment',
#   'guestfriendly',
#   'visually',
#   'appeal',
#   'environment',
#   'furnishing',
#   'decor',
#   'enhance',
#   'guest',
#   'theory',
#   'modeling',
#   'render',
#   'consider',
#   'aesthetic'],
#  'Investment Analyst': ['risk',
#   'investment',
#   'portfolio',
#   'analysis',
#   'asset',
#   'allocation',
#   'financial',
#   'assessment',
#   'optimization',
#   'manage',
#   'make',
#   'decision',
#   'conduct',
#   'modeling',
#   'tool',
#   'regulatory',
#   'compliance',
#   'evaluate',
#   'credit',
#   'operational',
#   'stress',
#   'test',
#   'implement',
#   'control'],
#  'Email Marketing Specialist': ['email',
#   'marketing',
#   'automation',
#   'campaign',
#   'deliverability',
#   'platform',
#   'eg',
#   'communication',
#   'skill',
#   'attention',
#   'detail',
#   'analysis',
#   'list',
#   'lead',
#   'nurture',
#   'workflow',
#   'create',
#   'testing',
#   'good',
#   'practice',
#   'troubleshoot',
#   'issue',
#   'sender',
#   'marketo',
#   'pardot',
#   'crm',
#   'optimization',
#   'set',
#   'manage',
#   'program',
#   'mailchimp',
#   'hubspot',
#   'audience',
#   'segmentation',
#   'ab',
#   'copywrite',
#   'htmlcss',
#   'plan',
#   'execute',
#   'segment'],
#  'Litigation Attorney': ['legal',
#   'family',
#   'law',
#   'court',
#   'divorce',
#   'proceeding',
#   'child',
#   'custody',
#   'mediation',
#   'client',
#   'representation',
#   'matter',
#   'litigation',
#   'corporate',
#   'counseling',
#   'specialize',
#   'adoption',
#   'advocate',
#   'offer',
#   'advice',
#   'service',
#   'case',
#   'counsel',
#   'dispute',
#   'contract',
#   'courtroom',
#   'preparation',
#   'writing',
#   'represent',
#   'civil',
#   'criminal',
#   'trial',
#   'present',
#   'prepare',
#   'argument',
#   'crossexamine',
#   'witness',
#   'negotiate',
#   'settlement',
#   'possible'],
#  'Registered Nurse': ['nursing',
#   'patient',
#   'care',
#   'clinical',
#   'oncology',
#   'education',
#   'staff',
#   'healthcare',
#   'team',
#   'assessment',
#   'specialization',
#   'eg',
#   'critical',
#   'advanced',
#   'skill',
#   'specialize',
#   'specific',
#   'area',
#   'pediatric',
#   'expert',
#   'guidance',
#   'contribute',
#   'evidencebase',
#   'practice',
#   'quality',
#   'improvement',
#   'leadership',
#   'charge',
#   'nurse',
#   'responsibilitie',
#   'coordination',
#   'supervise',
#   'allocate',
#   'assignment',
#   'compliance',
#   'standard',
#   'protocol',
#   'act',
#   'resource',
#   'nursingrelate'],
#  'Sales Manager': ['sale',
#   'team',
#   'leadership',
#   'key',
#   'account',
#   'relationship',
#   'client',
#   'development',
#   'territory',
#   'oversee',
#   'activity',
#   'specific',
#   'geographic',
#   'region',
#   'plan',
#   'objective',
#   'regional',
#   'competition',
#   'lead',
#   'manage',
#   'representative',
#   'set',
#   'target',
#   'goal',
#   'coach',
#   'negotiation',
#   'negotiate',
#   'contract',
#   'satisfaction',
#   'retention'],
#  'QA Analyst': ['test',
#   'testing',
#   'application',
#   'software',
#   'defect',
#   'automation',
#   'case',
#   'eg',
#   'selenium',
#   'execute',
#   'framework',
#   'stress',
#   'scenario',
#   'benchmarking',
#   'analysis',
#   'focus',
#   'scalability',
#   'responsiveness',
#   'bottleneck',
#   'quality',
#   'assurance',
#   'execution',
#   'tracking',
#   'perform',
#   'manual',
#   'issue',
#   'create',
#   'plan',
#   'developer',
#   'resolve',
#   'development',
#   'continuous',
#   'scripting',
#   'language',
#   'python',
#   'code',
#   'review',
#   'automated',
#   'script',
#   'tool'],
#  'Aerospace Engineer': ['system',
#   'aerospace',
#   'testing',
#   'aircraft',
#   'engineering',
#   'safety',
#   'troubleshoot',
#   'structural',
#   'analysis',
#   'regulation',
#   'software',
#   'communication',
#   'avionic',
#   'architecture',
#   'technical',
#   'documentation',
#   'configuration',
#   'work',
#   'optimization',
#   'address',
#   'reliability',
#   'multidisciplinary',
#   'team',
#   'cad',
#   'eg',
#   'autocad',
#   'aerodynamics',
#   'conduct',
#   'aerodynamic',
#   'compliance',
#   'aviation',
#   'avionics',
#   'systems',
#   'electronic',
#   'warfare',
#   'radar',
#   'validation',
#   'specialize',
#   'navigation',
#   'functionality'],
#  'Mechanical Designer': ['software',
#   'drawing',
#   'hvac',
#   'system',
#   'engineering',
#   'principle',
#   'collaboration',
#   'engineer',
#   'attention',
#   'detail',
#   'communication',
#   'skill',
#   'technical',
#   'energy',
#   'efficiency',
#   'compliance',
#   'mechanical',
#   'user',
#   'modeling',
#   'applicable',
#   'create',
#   'computeraide',
#   'cad',
#   'standard',
#   'calculation',
#   'autocad',
#   'similar',
#   'architect',
#   'regulatory',
#   'specialize',
#   'heating',
#   'ventilation',
#   'air',
#   'conditioning',
#   'calculate',
#   'requirement',
#   'select',
#   'equipment',
#   'prototype',
#   'wireframe'],
#  'Systems Engineer': ['cloud',
#   'system',
#   'infrastructure',
#   'azure',
#   'software',
#   'systems',
#   'engineering',
#   'eg',
#   'aws',
#   'devop',
#   'practice',
#   'automation',
#   'security',
#   'disaster',
#   'recovery',
#   'scalability',
#   'focus',
#   'computing',
#   'solution',
#   'aw',
#   'deploy',
#   'manage',
#   'cloudbased',
#   'service',
#   'resource',
#   'cost',
#   'efficiency',
#   'architecture',
#   'mapping',
#   'middleware',
#   'api',
#   'testing',
#   'troubleshoot',
#   'integrate',
#   'hardware',
#   'organization',
#   'seamless',
#   'flow',
#   'interoperability',
#   'developer'],
#  'Project Coordinator': ['project',
#   'scheduling',
#   'office',
#   'skill',
#   'construction',
#   'communication',
#   'team',
#   'budget',
#   'stakeholder',
#   'coordinate',
#   'timeline',
#   'assist',
#   'budgeting',
#   'cost',
#   'control',
#   'subcontractor',
#   'administration',
#   'organizational',
#   'time',
#   'microsoft',
#   'proficiency',
#   'administrative',
#   'support',
#   'meeting',
#   'manage',
#   'document',
#   'handle',
#   'prepare',
#   'presentation',
#   'expense',
#   'risk',
#   'assessment',
#   'mitigation',
#   'agile',
#   'waterfall',
#   'methodology',
#   'execution',
#   'task',
#   'communicate',
#   'member'],
#  'UI Developer': ['user',
#   'interface',
#   'experience',
#   'web',
#   'prototype',
#   'usability',
#   'testing',
#   'ux',
#   'html',
#   'css',
#   'javascript',
#   'ui',
#   'wireframing',
#   'tool',
#   'like',
#   'sketch',
#   'figma',
#   'focus',
#   'usercentered',
#   'principle',
#   'create',
#   'wireframe',
#   'conduct',
#   'gather',
#   'feedback',
#   'improvement',
#   'frontend',
#   'development',
#   'responsive',
#   'optimization',
#   'crossbrowser',
#   'compatibility',
#   'website',
#   'application',
#   'write',
#   'efficient',
#   'code',
#   'designer',
#   'seamless'],
#  'Graphic Designer': ['user',
#   'interface',
#   'ui',
#   'print',
#   'experience',
#   'ux',
#   'usability',
#   'testing',
#   'eg',
#   'graphic',
#   'tool',
#   'website',
#   'material',
#   'web',
#   'digital',
#   'wireframing',
#   'prototyping',
#   'sketch',
#   'figma',
#   'information',
#   'architecture',
#   'interaction',
#   'mobile',
#   'responsive',
#   'focus',
#   'application',
#   'enhance',
#   'engagement',
#   'conduct',
#   'developer',
#   'implement',
#   'adobe',
#   'layout',
#   'creative',
#   'suite',
#   'principle',
#   'visual',
#   'communication',
#   'typography',
#   'creativity'],
#  'Social Media Coordinator': ['content',
#   'video',
#   'social',
#   'medium',
#   'audience',
#   'creation',
#   'eg',
#   'writing',
#   'edit',
#   'graphic',
#   'production',
#   'seo',
#   'optimization',
#   'creative',
#   'storytelle',
#   'engagement',
#   'adaptability',
#   'communication',
#   'skill',
#   'creativity',
#   'create',
#   'compelling',
#   'shareable',
#   'platform',
#   'text',
#   'image',
#   'designer',
#   'photographer',
#   'visual',
#   'engage',
#   'respond',
#   'comment'],
#  'Family Nurse Practitioner': ['pediatric',
#   'healthcare',
#   'patient',
#   'care',
#   'geriatric',
#   'assessment',
#   'treatment',
#   'health',
#   'child',
#   'pharmacology',
#   'elderly',
#   'medical',
#   'diagnosis',
#   'education',
#   'specialize',
#   'address',
#   'unique',
#   'need',
#   'administer',
#   'vaccination',
#   'wellchild',
#   'checkup',
#   'educate',
# ...
#   'hardware',
#   'subject',
#   'matter',
#   'expert',
#   'engineer'],
#  'Chemical Engineer': ['quality',
#   'analysis',
#   'development',
#   'team',
#   'attention',
#   'detail',
#   'technical',
#   'control',
#   'innovation',
#   'crossfunctional',
#   'project',
#   'testing',
#   'assurance',
#   'standard',
#   'issue',
#   'collaboration',
#   'conduct',
#   'experiment',
#   'statistical',
#   'root',
#   'cause',
#   'production',
#   'prototype',
#   'experimentation',
#   'expertise',
#   'skill',
#   'work',
#   'new',
#   'material',
#   'test',
#   'eg',
#   'iso',
#   'inspection',
#   'technique',
#   'document',
#   'communication',
#   'focus',
#   'procedure',
#   'investigate',
#   'resolve'],
#  'HR Manager': ['hr',
#   'employee',
#   'development',
#   'relation',
#   'policy',
#   'skill',
#   'leadership',
#   'program',
#   'compliance',
#   'strategic',
#   'talent',
#   'oversee',
#   'function',
#   'recruitment',
#   'benefit',
#   'administration',
#   'align',
#   'goal',
#   'team',
#   'engagement',
#   'coach',
#   'mentor',
#   'focus',
#   'career',
#   'advancement',
#   'create',
#   'succession',
#   'plan',
#   'foster',
#   'culture',
#   'continuous',
#   'employment',
#   'law',
#   'auditing',
#   'communication',
#   'practice',
#   'comply',
#   'legal',
#   'regulatory',
#   'requirement'],
#  'Pharmaceutical Sales Representative': ['sale',
#   'healthcare',
#   'relationship',
#   'medical',
#   'territory',
#   'team',
#   'professional',
#   'technique',
#   'regulation',
#   'building',
#   'crm',
#   'software',
#   'usage',
#   'negotiation',
#   'closing',
#   'skill',
#   'promote',
#   'sell',
#   'pharmaceutical',
#   'doctor',
#   'pharmacist',
#   'customer',
#   'information',
#   'education',
#   'leadership',
#   'analysis',
#   'strategic',
#   'execution',
#   'manage',
#   'target',
#   'lead',
#   'coaching',
#   'support',
#   'progress',
#   'goal',
#   'understanding',
#   'forecasting',
#   'plan',
#   'focus',
#   'equipment'],
#  'Marketing Director': ['marketing',
#   'brand',
#   'relation',
#   'digital',
#   'communication',
#   'content',
#   'medium',
#   'manage',
#   'public',
#   'crisis',
#   'identity',
#   'campaign',
#   'seo',
#   'sem',
#   'lead',
#   'effort',
#   'create',
#   'collateral',
#   'press',
#   'release',
#   'development',
#   'creative',
#   'direction',
#   'strengthen',
#   'consistent',
#   'messaging',
#   'visual',
#   'position',
#   'reputation',
#   'team',
#   'leadership',
#   'proficiency',
#   'oversee',
#   'social',
#   'metric',
#   'budget'],
#  'Product Manager': ['development',
#   'stakeholder',
#   'agile',
#   'team',
#   'technical',
#   'roadmap',
#   'prioritize',
#   'backlog',
#   'principle',
#   'background',
#   'methodology',
#   'analysis',
#   'communication',
#   'skill',
#   'define',
#   'requirement',
#   'feature',
#   'deliver',
#   'create',
#   'release',
#   'plan',
#   'gather',
#   'incorporate',
#   'feedback',
#   'scrum',
#   'kanban',
#   'frameworks',
#   'user',
#   'story',
#   'write',
#   'prioritization',
#   'technique',
#   'collaboration',
#   'vision',
#   'act',
#   'owner',
#   'make',
#   'critical',
#   'decision',
#   'goal'],
#  'Procurement Coordinator': ['procurement',
#   'negotiation',
#   'vendor',
#   'supplier',
#   'control',
#   'relation',
#   'coordinate',
#   'purchasing',
#   'activity',
#   'source',
#   'create',
#   'purchase',
#   'order',
#   'delivery',
#   'costeffective'],
#  'Supply Chain Analyst': ['analysis'],
#  'Network Technician': ['network',
#   'security',
#   'configuration',
#   'troubleshoot',
#   'support',
#   'technical',
#   'issue',
#   'cybersecurity',
#   'intrusion',
#   'detection',
#   'analysis',
#   'firewall',
#   'focus',
#   'implement',
#   'measure',
#   'protect',
#   'cyber',
#   'threat',
#   'traffic',
#   'anomaly',
#   'breach',
#   'conduct',
#   'audits',
#   'recommend',
#   'improvement',
#   'resolve',
#   'connectivity',
#   'problem',
#   'enduser',
#   'networkrelated',
#   'challenge',
#   'document'],
#  'UX Researcher': ['user',
#   'usability',
#   'testing',
#   'assessment',
#   'ux',
#   'plan',
#   'conduct',
#   'interface',
#   'tool',
#   'technique',
#   'focus',
#   'digital',
#   'website',
#   'create',
#   'test',
#   'scenario',
#   'gather',
#   'area',
#   'improvement',
#   'experience',
#   'journey',
#   'mapping',
#   'thinking',
#   'roadmap',
#   'base',
#   'goal',
#   'development',
#   'team',
#   'implement',
#   'enhancement',
#   'exist',
#   'method',
#   'analysis',
#   'interpretation',
#   'understand',
#   'behavior',
#   'need',
#   'preference',
#   'execute',
#   'interview'],
#  'Social Worker': ['child',
#   'counseling',
#   'assessment',
#   'intervention',
#   'mental',
#   'health',
#   'crisis',
#   'empathy',
#   'cultural',
#   'competence',
#   'documentation',
#   'communication',
#   'plan',
#   'student',
#   'family',
#   'treatment',
#   'licensing',
#   'certification',
#   'school',
#   'social',
#   'education',
#   'support',
#   'need',
#   'skill',
#   'technique',
#   'psychotherapy',
#   'ethical',
#   'standard',
#   'active',
#   'listen',
#   'skills',
#   'selfcare',
#   'offer',
#   'therapy',
#   'individual',
#   'group',
#   'diagnose',
#   'treat',
#   'condition',
#   'progress'],
#  'Finance Manager': ['financial',
#   'analysis',
#   'accounting',
#   'manage',
#   'team',
#   'oversee',
#   'treasury',
#   'cash',
#   'risk',
#   'investment',
#   'forecasting',
#   'principle',
#   'budget',
#   'function',
#   'compliance',
#   'accurate',
#   'timely',
#   'statement',
#   'audits',
#   'tax',
#   'filing',
#   'flow',
#   'banking',
#   'relation',
#   'operation',
#   'assessment',
#   'work',
#   'capital',
#   'interest',
#   'rate',
#   'leadership',
#   'wealth',
#   'client',
#   'advisory',
#   'skill',
#   'budgeting',
#   'achieve',
#   'organizational',
#   'goal',
#   'guidance'],
#  'Event Planner': ['event',
#   'plan',
#   'wedding',
#   'vendor',
#   'coordination',
#   'corporate',
#   'budget',
#   'marketing',
#   'coordinate',
#   'manage',
#   'promotion',
#   'timeline',
#   'communicate',
#   'client',
#   'understand',
#   'goal',
#   'preference',
#   'smooth',
#   'execution',
#   'venue',
#   'selection',
#   'catering',
#   'menu',
#   'floral',
#   'decor',
#   'etiquette',
#   'specialize',
#   'assist',
#   'couple',
#   'create',
#   'dream',
#   'select',
#   'ceremony',
#   'handle',
#   'day',
#   'creative',
#   'budgetconscious',
#   'solution',
#   'brand',
#   'communication'],
#  'Network Security Specialist': ['security',
#   'incident',
#   'assessment',
#   'soc',
#   'alert',
#   'response',
#   'threat',
#   'detection',
#   'tool',
#   'eg',
#   'cybersecurity',
#   'audits',
#   'conduct',
#   'vulnerability',
#   'risk',
#   'policy',
#   'operation',
#   'log',
#   'analysis',
#   'idsip',
#   'triage',
#   'work',
#   'team',
#   'respond',
#   'investigate',
#   'documentation',
#   'intrusion',
#   'siem',
#   'scan',
#   'focus',
#   'implement',
#   'measure',
#   'protect',
#   'cyber',
#   'network',
#   'traffic',
#   'anomaly',
#   'breach',
#   'recommend',
#   'improvement'],
#  'IT Administrator': ['system',
#   'administration',
#   'security',
#   'server',
#   'network',
#   'troubleshoot',
#   'maintenance',
#   'backup',
#   'recovery',
#   'manage',
#   'computer',
#   'install',
#   'configure',
#   'software',
#   'hardware'],
#  'Customer Support Specialist': ['customer',
#   'communication',
#   'relationship',
#   'feedback',
#   'retention',
#   'strong',
#   'support',
#   'service',
#   'technical',
#   'issue',
#   'skill',
#   'ticket',
#   'resolution',
#   'onboarding',
#   'train',
#   'analysis',
#   'crossselle',
#   'upselle',
#   'empathy',
#   'advocacy',
#   'satisfaction',
#   'upsell',
#   'crosssell',
#   'gather',
#   'relay',
#   'improve',
#   'base',
#   'troubleshoot',
#   'help',
#   'desk',
#   'troubleshooting',
#   'tool',
#   'eg',
#   'zendesk',
#   'freshdesk',
#   'critical',
#   'thinking',
#   'creation',
#   'assistance',
#   'resolve'],
#  'Account Executive': ['client',
#   'sale',
#   'account',
#   'advertising',
#   'relationship',
#   'campaign',
#   'key',
#   'development',
#   'plan',
#   'negotiation',
#   'closing',
#   'skill',
#   'building',
#   'focus',
#   'strategic',
#   'serve',
#   'primary',
#   'point',
#   'contact',
#   'growth',
#   'high',
#   'satisfaction',
#   'retention',
#   'marketing',
#   'budget',
#   'medium',
#   'buy',
#   'manage',
#   'execution',
#   'creative',
#   'concept',
#   'insight',
#   'tactic',
#   'forecasting',
#   'pursue',
#   'new',
#   'exist',
#   'meet',
#   'exceed',
#   'target'],
#  'Back-End Developer': ['api',
#   'security',
#   'development',
#   'application',
#   'interface',
#   'serverside',
#   'database',
#   'restful',
#   'protocol',
#   'oauth',
#   'jwt',
#   'implement',
#   'apis',
#   'communication',
#   'different',
#   'software',
#   'system',
#   'compatibility',
#   'document',
#   'usage',
#   'specification',
#   'language',
#   'eg',
#   'java',
#   'python',
#   'logic',
#   'web',
#   'server',
#   'scalability',
#   'frontend',
#   'developer',
#   'integrate',
#   'user'],
#  'Event Manager': ['event',
#   'conference',
#   'marketing',
#   'budget',
#   'vendor',
#   'coordination',
#   'promotion',
#   'client',
#   'relation',
#   'specialize',
#   'convention',
#   'coordinate',
#   'speaker',
#   'session',
#   'exhibitor',
#   'attendee',
#   'experience',
#   'oversee',
#   'registration'],
#  'IT Manager': ['network',
#   'system',
#   'infrastructure',
#   'administration',
#   'eg',
#   'security',
#   'cloud',
#   'vendor',
#   'plan',
#   'strategic',
#   'leadership',
#   'virtualization',
#   'vmware',
#   'hyperv',
#   'storage',
#   'disaster',
#   'recovery',
#   'capacity',
#   'monitoring',
#   'troubleshoot',
#   'aws',
#   'azure',
#   'manage',
#   'server',
#   'center',
#   'high',
#   'scalability',
#   'implement',
#   'upgrade',
#   'budgeting',
#   'financial',
#   'governance',
#   'compliance',
#   'cybersecurity',
#   'risk',
#   'project',
#   'computing',
#   'enterprise',
#   'software',
#   'department'],
#  'Legal Advisor': ['legal',
#   'corporate',
#   'contract',
#   'compliance',
#   'counsel',
#   'law',
#   'client',
#   'merger',
#   'acquisition',
#   'governance',
#   'risk',
#   'draft',
#   'advice',
#   'negotiation',
#   'regulatory',
#   'organization',
#   'inhouse',
#   'diligence',
#   'specialize',
#   'advise',
#   'company',
#   'mitigation',
#   'regulation',
#   'handle',
#   'transaction',
#   'litigation',
#   'support',
#   'representation',
#   'writing',
#   'individual',
#   'matter',
#   'document',
#   'agreement',
#   'represent',
#   'proceeding',
#   'advisory',
#   'employment',
#   'intellectual',
#   'property',
#   'dispute'],
#  'Database Developer': ['database',
#   'query',
#   'sql',
#   'nosql',
#   'store',
#   'mongodb',
#   'cassandra',
#   'scalability',
#   'structure',
#   'language',
#   'optimization',
#   'modeling',
#   'maintenance',
#   'skill',
#   'integrity',
#   'write',
#   'complex',
#   'procedure',
#   'troubleshoot',
#   'issue',
#   'eg',
#   'migration',
#   'tune',
#   'distribute',
#   'system',
#   'work',
#   'like',
#   'retrieve',
#   'efficiently'],
#  'Paralegal': ['legal',
#   'proficiency',
#   'real',
#   'estate',
#   'document',
#   'communication',
#   'corporate',
#   'transaction',
#   'preparation',
#   'attention',
#   'detail',
#   'skill',
#   'software',
#   'contract',
#   'title',
#   'search',
#   'closing',
#   'review',
#   'terminology',
#   'record',
#   'trial',
#   'client',
#   'support',
#   'assist',
#   'compliance',
#   'diligence',
#   'deed',
#   'professional',
#   'specialize',
#   'property',
#   'zoning',
#   'regulation',
#   'coordinate',
#   'discovery',
#   'case',
#   'efile',
#   'multitaske',
#   'attorney',
#   'prepare',
#   'hearing'],
#  'Sales Consultant': ['sale',
#   'client',
#   'customer',
#   'relationship',
#   'technique',
#   'skill',
#   'negotiation',
#   'target',
#   'businesstobusiness',
#   'acquisition',
#   'expert',
#   'advice',
#   'guidance',
#   'service',
#   'understand',
#   'need',
#   'recommend',
#   'appropriate',
#   'solution',
#   'achieve',
#   'quota',
#   'coach',
#   'program',
#   'development',
#   'presentation',
#   'train',
#   'onboard',
#   'new',
#   'team',
#   'member',
#   'material',
#   'script',
#   'conduct',
#   'coaching',
#   'lead',
#   'generation',
#   'building',
#   'specialize',
#   'corporate',
#   'longterm'],
#  'Project Manager': ['project',
#   'team',
#   'agile',
#   'budget',
#   'risk',
#   'manage',
#   'oversee',
#   'leadership',
#   'communication',
#   'skill',
#   'plan',
#   'successful',
#   'delivery',
#   'scope',
#   'time',
#   'define',
#   'objective',
#   'requirement',
#   'progress',
#   'construction',
#   'safety',
#   'regulation',
#   'methodology',
#   'scrum',
#   'kanban',
#   'collaboration',
#   'tool',
#   'eg',
#   'jira',
#   'facilitate',
#   'development',
#   'crossfunctional',
#   'backlog',
#   'sprint',
#   'coach',
#   'mentor',
#   'member',
#   'practice',
#   'drive',
#   'continuous'],
#  'Chemical Analyst': ['chemical',
#   'quality',
#   'analysis',
#   'scientific',
#   'control',
#   'laboratory',
#   'chemistry',
#   'testing',
#   'documentation',
#   'analytical',
#   'technique',
#   'instrumentation',
#   'sample',
#   'preparation',
#   'software',
#   'eg',
#   'chemdraw',
#   'perform',
#   'experiment',
#   'quantify',
#   'substance',
#   'operate',
#   'equipment',
#   'instrument',
#   'document',
#   'test',
#   'result',
#   'experimental',
#   'interpretation',
#   'synthesis',
#   'protocol',
#   'writing',
#   'skill',
#   'conduct',
#   'property',
#   'reaction',
#   'formulation',
#   'new',
#   'compound',
#   'project'],
#  'Financial Analyst': ['financial',
#   'investment',
#   'analysis',
#   'budget',
#   'prepare',
#   'plan',
#   'retirement',
#   'portfolio',
#   'decision',
#   'economic',
#   'presentation',
#   'forecasting',
#   'excel',
#   'proficiency',
#   'manage',
#   'department',
#   'head',
#   'create',
#   'tax',
#   'assist',
#   'client',
#   'conduct',
#   'comprehensive',
#   'assessment',
#   'personalize',
#   'advice'],
#  'Art Teacher': ['art',
#   'artistic',
#   'skill',
#   'student',
#   'teach',
#   'creativity',
#   'lesson',
#   'communication',
#   'instruction',
#   'technique',
#   'assessment',
#   'education',
#   'curriculum',
#   'program',
#   'development',
#   'ability',
#   'history',
#   'fine',
#   'draw',
#   'painting',
#   'sculpture',
#   'age',
#   'execute',
#   'plan',
#   'foster',
#   'expression',
#   'classroom',
#   'focus',
#   'specific',
#   'medium',
#   'studio',
#   'environment',
#   'handson',
#   'guidance',
#   'encourage',
#   'explore',
#   'refine',
#   'teacher',
#   'train',
#   'expertise'],
#  'IT Support Specialist': ['system',
#   'hardware',
#   'software',
#   'desktop',
#   'support',
#   'skill',
#   'upgrade',
#   'troubleshooting',
#   'customer',
#   'service',
#   'technical',
#   'enduser',
#   'issue',
#   'resolve',
#   'network',
#   'server',
#   'backup',
#   'recovery',
#   'operating',
#   'expertise',
#   'eg',
#   'windows',
#   'macos',
#   'remote',
#   'install',
#   'configure',
#   'computer',
#   'peripheral',
#   'perform',
#   'repair',
#   'manage',
#   'asset',
#   'tracking',
#   'communication',
#   'ticket',
#   'usage',
#   'basic',
#   'criticalthinke',
#   'troubleshoot',
#   'itrelate'],
#  'Personal Assistant': ['personal',
#   'communication',
#   'skill',
#   'administrative',
#   'support',
#   'calendar',
#   'time',
#   'organizational',
#   'confidentiality',
#   'act',
#   'secretary',
#   'manage',
#   'appointment',
#   'task',
#   'handle',
#   'correspondence',
#   'behalf',
#   'employer',
#   'organize',
#   'schedule',
#   'commitment'],
#  'Market Analyst': ['analysis'],
#  'HR Generalist': ['recruitment',
#   'record',
#   'human',
#   'resource',
#   'employee',
#   'onboarde',
#   'hris',
#   'hr',
#   'information',
#   'system',
#   'keep',
#   'communication',
#   'skill',
#   'assist',
#   'activity',
#   'post',
#   'job',
#   'opening',
#   'coordinate',
#   'interview',
#   'manage',
#   'applicant',
#   'positive',
#   'candidate',
#   'experience',
#   'metric'],
#  'Veterinarian': ['care',
#   'exotic',
#   'animal',
#   'medicine',
#   'equine',
#   'horse',
#   'pet',
#   'diagnostic',
#   'surgical',
#   'compassion',
#   'empathy',
#   'client',
#   'communication',
#   'attention',
#   'detail',
#   'owner',
#   'surgery',
#   'health',
#   'reptile',
#   'skill',
#   'anesthesia',
#   'medical',
#   'specialize',
#   'treatment',
#   'specie',
#   'veterinary',
#   'perform',
#   'avian',
#   'amphibian',
#   'focus',
#   'need',
#   'nontraditional',
#   'bird',
#   'mammal',
#   'specialized',
#   'unique',
#   'educate',
#   'proper',
#   'small',
#   'preventive'],
#  'Sales Associate': ['customer',
#   'sale',
#   'handle',
#   'store',
#   'service',
#   'technique',
#   'cash',
#   'communication',
#   'skill',
#   'assist',
#   'retail',
#   'answer',
#   'question',
#   'information',
#   'transaction',
#   'inquiry',
#   'return',
#   'display',
#   'merchandising'],
#  'Investment Advisor': ['financial',
#   'investment',
#   'skill',
#   'client',
#   'relationship',
#   'communication',
#   'analytical',
#   'advice',
#   'goal',
#   'risk',
#   'tolerance',
#   'create',
#   'personalize',
#   'portfolio'],
#  'Financial Planner': ['tax',
#   'law',
#   'financial',
#   'client',
#   'optimization',
#   'analysis',
#   'retirement',
#   'estate',
#   'relationship',
#   'communication',
#   'skill',
#   'attention',
#   'detail',
#   'software',
#   'proficiency',
#   'regulatory',
#   'compliance',
#   'focus',
#   'help',
#   'minimize',
#   'liability',
#   'stay',
#   'update',
#   'regulation',
#   'taxefficient']}

# %%
# Preprocessing function for CV
def preprocess_text(text):
    text = re.sub(r'[^\w\s]', '', text.lower())
    doc = nlp(text)
    tokens = [token.lemma_ for token in doc if token.is_alpha and not token.is_stop and token.lemma_ not in generic_terms]
    return tokens

# Function to extract keywords from CV
def extract_cv_keywords(text):
    tokens = preprocess_text(text)
    return list(set(tokens))  # Unique keywords

# %%
def jaccard_similarity(set1, set2):
    intersection = len(set1.intersection(set2))
    union = len(set1.union(set2))
    return intersection / union if union > 0 else 0

# Function to find top 3 job titles and missing keywords
def find_top_jobs_and_missing_keywords(text_cv):
    cv_keywords = set(extract_cv_keywords(text_cv))
    job_similarities = []
    for job_title, job_keywords in skill_map.items():
        job_keywords_set = set(job_keywords)
        similarity = jaccard_similarity(cv_keywords, job_keywords_set)
        missing_keywords = list(job_keywords_set - cv_keywords)
        job_similarities.append((job_title, similarity, missing_keywords))
    
    job_similarities.sort(key=lambda x: x[1], reverse=True)
    top_3_jobs = job_similarities[:3]
    
    result = []
    for job_title, similarity, missing_keywords in top_3_jobs:
        result.append({
            'job_title': job_title,
            'similarity': round(similarity, 3),
            'missing_keywords': missing_keywords
        })
    
    return result

# %%
text_cv = """
im machine learning and ai engineering
"""
top_jobs = find_top_jobs_and_missing_keywords(text_cv)

# Print results
for job in top_jobs:
    print(f"Job Title: {job['job_title']}")
    print(f"Similarity: {job['similarity']}")
    print(f"Missing Keywords: {', '.join(job['missing_keywords']) if job['missing_keywords'] else 'None'}")
    print()
# Out:
# Job Title: Process Engineer
# Similarity: 0.03
# Missing Keywords: lean, industrial, control, reaction, waste, operation, skill, safety, protocol, technique, sigma, laboratory, chemical, focus, system, improve, streamline, environmental, reduce, methodology, workflow, quality, optimization, implement, regulation, productivity, manufacturing, specialize, analysis, compliance
#
# Job Title: Electrical Engineer
# Similarity: 0.024
# Missing Keywords: power, instrumentation, network, validation, embed, energy, component, circuit, plc, solution, grid, application, implement, testing, transmission, flow, layout, crossfunctional, reliability, efficiency, analysis, pcb, control, team, safety, system, troubleshoot, electrical, hardware, automation, development, electronic, perform, distribution, robotic, regulation, renewable, conduct, industrial
#
# Job Title: Electrical Designer
# Similarity: 0.024
# Missing Keywords: plan, project, proficiency, manufacturability, software, energy, component, circuit, lighting, autocad, select, building, exterior, visual, concept, quality, fixture, layout, efficiency, architectural, schematic, pcb, control, interior, light, infrastructure, appeal, print, creative, board, system, electrical, create, electronic, enhance, electronics, specialize, device, technical
